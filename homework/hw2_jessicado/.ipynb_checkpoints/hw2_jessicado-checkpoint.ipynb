# %% [markdown]
# Problem 1: ![image.png](attachment:c87ca00f-d6a7-409e-a0b0-f3f3d66bbe20.png)![image.png](attachment:d766543c-8041-4531-baaa-2dc6be905f08.png)

# %% [markdown]
# Problem 2:
# ![image.png](attachment:cba21fda-35fc-45b1-a7fd-fd49f0af5f22.png)![image.png](attachment:e72a8529-246d-4fb6-95a5-8b3df1db7470.png)

# %% [markdown]
# Hello! This is my first practice notebook :)

# %%
x = 10
y = 100

z = x * y
w = y-z

print (z)
print (w)
# Out:
# 1000
# -900

# %%
min = 3
# Min is not a good variable name as it is a function in Python to find lowest number

# %%
## Make a variable q equal to 1. Print q. Add one to q. Print q. In one line multiply q by 10 and print the result.

q = 1
print(q)
q + 1
print (q+1)
print (q*10)
# Out:
# 1
# 2
# 10
